# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import glob
import tabulate
import pprint
import click
import numpy as np
import pandas as pd
from ray.tune.commands import *
from nupic.research.frameworks.dynamic_sparse.common.browser import *

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set(style="whitegrid")
sns.set_palette("colorblind")

# %%
base = 'gsc-plots-2019-10-21'
exps = [
    os.path.join(base, exp) for exp in [
        'gsc-Static', 
    ]
]
paths = [os.path.expanduser("~/nta/results/{}".format(e)) for e in exps]
df = load_many(paths)
# Out:
# gsc-Static
# coactivations_layer-1 0     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 1     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 2     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 3     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 4     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 5     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 6     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 7     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 8     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 9     {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 10    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 11    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 12    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 13    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 14    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 15    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 16    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 17    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 18    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 19    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 20    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 21    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 22    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 23    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 24    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 25    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 26    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 27    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 28    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# 29    {'data': 0      0.0\n1      0.0\n2      0.0\n3...
# Name: coactivations_layer-1, dtype: object
# coactivations_layer-6 0     {'data': 0        515.0\n1        515.0\n2    ...
# 1     {'data': 0        572.0\n1        572.0\n2    ...
# 2     {'data': 0         631.0\n1         631.0\n2  ...
# 3     {'data': 0        428.0\n1        428.0\n2    ...
# 4     {'data': 0        779.0\n1        779.0\n2    ...
# 5     {'data': 0        651.0\n1        651.0\n2    ...
# 6     {'data': 0        663.0\n1        663.0\n2    ...
# 7     {'data': 0        712.0\n1        712.0\n2    ...
# 8     {'data': 0        697.0\n1        697.0\n2    ...
# 9     {'data': 0         934.0\n1         934.0\n2  ...
# 10    {'data': 0        801.0\n1        801.0\n2    ...
# 11    {'data': 0        890.0\n1        890.0\n2    ...
# 12    {'data': 0        453.0\n1        453.0\n2    ...
# 13    {'data': 0         890.0\n1         890.0\n2  ...
# 14    {'data': 0        593.0\n1        593.0\n2    ...
# 15    {'data': 0         627.0\n1         627.0\n2  ...
# 16    {'data': 0        747.0\n1        747.0\n2    ...
# 17    {'data': 0         867.0\n1         867.0\n2  ...
# 18    {'data': 0        695.0\n1        695.0\n2    ...
# 19    {'data': 0        778.0\n1        778.0\n2    ...
# 20    {'data': 0         696.0\n1         696.0\n2  ...
# 21    {'data': 0        737.0\n1        737.0\n2    ...
# 22    {'data': 0        938.0\n1        938.0\n2    ...
# 23    {'data': 0        657.0\n1        657.0\n2    ...
# 24    {'data': 0        816.0\n1        816.0\n2    ...
# 25    {'data': 0        831.0\n1        831.0\n2    ...
# 26    {'data': 0        883.0\n1        883.0\n2    ...
# 27    {'data': 0         751.0\n1         751.0\n2  ...
# 28    {'data': 0        737.0\n1        737.0\n2    ...
# 29    {'data': 0        785.0\n1        785.0\n2    ...
# Name: coactivations_layer-6, dtype: object
# coacts_01_layer-6 0     {'data': 0        395.0\n1        418.0\n2    ...
# 1     {'data': 0        329.0\n1        342.0\n2    ...
# 2     {'data': 0        423.0\n1        430.0\n2    ...
# 3     {'data': 0        384.0\n1        371.0\n2    ...
# 4     {'data': 0        390.0\n1        362.0\n2    ...
# 5     {'data': 0        555.0\n1        554.0\n2    ...
# 6     {'data': 0        482.0\n1        479.0\n2    ...
# 7     {'data': 0        284.0\n1        260.0\n2    ...
# 8     {'data': 0        418.0\n1        405.0\n2    ...
# 9     {'data': 0        513.0\n1        492.0\n2    ...
# 10    {'data': 0        378.0\n1        364.0\n2    ...
# 11    {'data': 0        401.0\n1        365.0\n2    ...
# 12    {'data': 0        207.0\n1        189.0\n2    ...
# 13    {'data': 0        407.0\n1        371.0\n2    ...
# 14    {'data': 0        291.0\n1        262.0\n2    ...
# 15    {'data': 0        346.0\n1        321.0\n2    ...
# 16    {'data': 0        356.0\n1        338.0\n2    ...
# 17    {'data': 0        409.0\n1        380.0\n2    ...
# 18    {'data': 0        347.0\n1        343.0\n2    ...
# 19    {'data': 0        369.0\n1        355.0\n2    ...
# 20    {'data': 0        360.0\n1        325.0\n2    ...
# 21    {'data': 0        343.0\n1        355.0\n2    ...
# 22    {'data': 0        426.0\n1        410.0\n2    ...
# 23    {'data': 0        383.0\n1        352.0\n2    ...
# 24    {'data': 0        383.0\n1        350.0\n2    ...
# 25    {'data': 0        411.0\n1        401.0\n2    ...
# 26    {'data': 0        416.0\n1        405.0\n2    ...
# 27    {'data': 0        352.0\n1        351.0\n2    ...
# 28    {'data': 0        348.0\n1        350.0\n2    ...
# 29    {'data': 0        368.0\n1        361.0\n2    ...
# Name: coacts_01_layer-6, dtype: object
# coacts_10_layer-6 0     {'data': 0        2201.0\n1        2195.0\n2  ...
# 1     {'data': 0        2291.0\n1        2294.0\n2  ...
# 2     {'data': 0        2159.0\n1        2217.0\n2  ...
# 3     {'data': 0        1893.0\n1        1898.0\n2  ...
# 4     {'data': 0        2270.0\n1        2270.0\n2  ...
# 5     {'data': 0        1800.0\n1        1751.0\n2  ...
# 6     {'data': 0        2121.0\n1        2059.0\n2  ...
# 7     {'data': 0        2299.0\n1        2248.0\n2  ...
# 8     {'data': 0        2242.0\n1        2234.0\n2  ...
# 9     {'data': 0        2131.0\n1        2175.0\n2  ...
# 10    {'data': 0        2530.0\n1        2536.0\n2  ...
# 11    {'data': 0        2620.0\n1        2504.0\n2  ...
# 12    {'data': 0        2804.0\n1        2822.0\n2  ...
# 13    {'data': 0        2491.0\n1        2504.0\n2  ...
# 14    {'data': 0        2600.0\n1        2622.0\n2  ...
# 15    {'data': 0        2569.0\n1        2502.0\n2  ...
# 16    {'data': 0        2509.0\n1        2452.0\n2  ...
# 17    {'data': 0        2458.0\n1        2448.0\n2  ...
# 18    {'data': 0        2474.0\n1        2476.0\n2  ...
# 19    {'data': 0        2492.0\n1        2452.0\n2  ...
# 20    {'data': 0        2534.0\n1        2519.0\n2  ...
# 21    {'data': 0        2495.0\n1        2508.0\n2  ...
# 22    {'data': 0        2436.0\n1        2439.0\n2  ...
# 23    {'data': 0        2342.0\n1        2314.0\n2  ...
# 24    {'data': 0        2568.0\n1        2561.0\n2  ...
# 25    {'data': 0        2429.0\n1        2370.0\n2  ...
# 26    {'data': 0        2388.0\n1        2450.0\n2  ...
# 27    {'data': 0        2468.0\n1        2456.0\n2  ...
# 28    {'data': 0        2568.0\n1        2526.0\n2  ...
# 29    {'data': 0        2585.0\n1        2489.0\n2  ...
# Name: coacts_10_layer-6, dtype: object
# coacts_00_layer-6 0     {'data': 0        1929.0\n1        1935.0\n2  ...
# 1     {'data': 0        1865.0\n1        1862.0\n2  ...
# 2     {'data': 0        1892.0\n1        1834.0\n2  ...
# 3     {'data': 0        2302.0\n1        2297.0\n2  ...
# 4     {'data': 0        1708.0\n1        1708.0\n2  ...
# 5     {'data': 0        2094.0\n1        2143.0\n2  ...
# 6     {'data': 0        1817.0\n1        1879.0\n2  ...
# 7     {'data': 0        1767.0\n1        1818.0\n2  ...
# 8     {'data': 0        1776.0\n1        1784.0\n2  ...
# 9     {'data': 0        1656.0\n1        1612.0\n2  ...
# 10    {'data': 0        1454.0\n1        1448.0\n2  ...
# 11    {'data': 0        1290.0\n1        1406.0\n2  ...
# 12    {'data': 0        1530.0\n1        1512.0\n2  ...
# 13    {'data': 0        1402.0\n1        1389.0\n2  ...
# 14    {'data': 0        1602.0\n1        1580.0\n2  ...
# 15    {'data': 0        1564.0\n1        1631.0\n2  ...
# 16    {'data': 0        1530.0\n1        1587.0\n2  ...
# 17    {'data': 0        1461.0\n1        1471.0\n2  ...
# 18    {'data': 0        1605.0\n1        1603.0\n2  ...
# 19    {'data': 0        1512.0\n1        1552.0\n2  ...
# 20    {'data': 0        1545.0\n1        1560.0\n2  ...
# 21    {'data': 0        1551.0\n1        1538.0\n2  ...
# 22    {'data': 0        1419.0\n1        1416.0\n2  ...
# 23    {'data': 0        1749.0\n1        1777.0\n2  ...
# 24    {'data': 0        1403.0\n1        1410.0\n2  ...
# 25    {'data': 0        1512.0\n1        1571.0\n2  ...
# 26    {'data': 0        1506.0\n1        1444.0\n2  ...
# 27    {'data': 0        1564.0\n1        1576.0\n2  ...
# 28    {'data': 0        1472.0\n1        1514.0\n2  ...
# 29    {'data': 0        1414.0\n1        1510.0\n2  ...
# Name: coacts_00_layer-6, dtype: object
# coactivations_layer-12 0     {'data': 0         134.0\n1         250.0\n2  ...
# 1     {'data': 0          70.0\n1         138.0\n2  ...
# 2     {'data': 0          57.0\n1         217.0\n2  ...
# 3     {'data': 0          54.0\n1         172.0\n2  ...
# 4     {'data': 0         125.0\n1         274.0\n2  ...
# 5     {'data': 0         123.0\n1         339.0\n2  ...
# 6     {'data': 0          53.0\n1         233.0\n2  ...
# 7     {'data': 0          82.0\n1         211.0\n2  ...
# 8     {'data': 0          67.0\n1         304.0\n2  ...
# 9     {'data': 0         133.0\n1         255.0\n2  ...
# 10    {'data': 0          53.0\n1         119.0\n2  ...
# 11    {'data': 0         128.0\n1         196.0\n2  ...
# 12    {'data': 0          98.0\n1         290.0\n2  ...
# 13    {'data': 0         101.0\n1         227.0\n2  ...
# 14    {'data': 0          67.0\n1         236.0\n2  ...
# 15    {'data': 0          60.0\n1         490.0\n2  ...
# 16    {'data': 0          28.0\n1         198.0\n2  ...
# 17    {'data': 0          83.0\n1         305.0\n2  ...
# 18    {'data': 0          63.0\n1         240.0\n2  ...
# 19    {'data': 0          46.0\n1         221.0\n2  ...
# 20    {'data': 0          75.0\n1         234.0\n2  ...
# 21    {'data': 0          82.0\n1         208.0\n2  ...
# 22    {'data': 0         147.0\n1         254.0\n2  ...
# 23    {'data': 0          89.0\n1         240.0\n2  ...
# 24    {'data': 0          79.0\n1         241.0\n2  ...
# 25    {'data': 0          68.0\n1         225.0\n2  ...
# 26    {'data': 0         100.0\n1         244.0\n2  ...
# 27    {'data': 0         112.0\n1         310.0\n2  ...
# 28    {'data': 0          98.0\n1         315.0\n2  ...
# 29    {'data': 0          92.0\n1         300.0\n2  ...
# Name: coactivations_layer-12, dtype: object
# coacts_01_layer-12 0     {'data': 0         363.0\n1         247.0\n2  ...
# 1     {'data': 0         294.0\n1         226.0\n2  ...
# 2     {'data': 0         401.0\n1         241.0\n2  ...
# 3     {'data': 0         356.0\n1         238.0\n2  ...
# 4     {'data': 0         409.0\n1         260.0\n2  ...
# 5     {'data': 0         439.0\n1         223.0\n2  ...
# 6     {'data': 0         373.0\n1         193.0\n2  ...
# 7     {'data': 0         403.0\n1         274.0\n2  ...
# 8     {'data': 0         381.0\n1         144.0\n2  ...
# 9     {'data': 0         380.0\n1         258.0\n2  ...
# 10    {'data': 0         272.0\n1         206.0\n2  ...
# 11    {'data': 0         323.0\n1         255.0\n2  ...
# 12    {'data': 0         401.0\n1         209.0\n2  ...
# 13    {'data': 0         419.0\n1         293.0\n2  ...
# 14    {'data': 0         385.0\n1         216.0\n2  ...
# 15    {'data': 0         548.0\n1         118.0\n2  ...
# 16    {'data': 0         284.0\n1         114.0\n2  ...
# 17    {'data': 0         435.0\n1         213.0\n2  ...
# 18    {'data': 0         409.0\n1         232.0\n2  ...
# 19    {'data': 0         321.0\n1         146.0\n2  ...
# 20    {'data': 0         357.0\n1         198.0\n2  ...
# 21    {'data': 0         285.0\n1         159.0\n2  ...
# 22    {'data': 0         324.0\n1         217.0\n2  ...
# 23    {'data': 0         337.0\n1         186.0\n2  ...
# 24    {'data': 0         397.0\n1         235.0\n2  ...
# 25    {'data': 0         284.0\n1         127.0\n2  ...
# 26    {'data': 0         310.0\n1         166.0\n2  ...
# 27    {'data': 0         394.0\n1         196.0\n2  ...
# 28    {'data': 0         433.0\n1         216.0\n2  ...
# 29    {'data': 0         396.0\n1         188.0\n2  ...
# Name: coacts_01_layer-12, dtype: object
# coacts_10_layer-12 0     {'data': 0          690.0\n1         1305.0\n2...
# 1     {'data': 0          650.0\n1         1342.0\n2...
# 2     {'data': 0          664.0\n1         1275.0\n2...
# 3     {'data': 0          591.0\n1         1188.0\n2...
# 4     {'data': 0          832.0\n1         1129.0\n2...
# 5     {'data': 0          855.0\n1         1155.0\n2...
# 6     {'data': 0          705.0\n1         1278.0\n2...
# 7     {'data': 0          584.0\n1         1148.0\n2...
# 8     {'data': 0          658.0\n1         1343.0\n2...
# 9     {'data': 0          745.0\n1         1345.0\n2...
# 10    {'data': 0          699.0\n1         1332.0\n2...
# 11    {'data': 0          807.0\n1         1244.0\n2...
# 12    {'data': 0          471.0\n1         1381.0\n2...
# 13    {'data': 0          677.0\n1         1260.0\n2...
# 14    {'data': 0          469.0\n1         1297.0\n2...
# 15    {'data': 0          481.0\n1         1345.0\n2...
# 16    {'data': 0          525.0\n1         1447.0\n2...
# 17    {'data': 0          639.0\n1         1320.0\n2...
# 18    {'data': 0          536.0\n1         1332.0\n2...
# 19    {'data': 0          588.0\n1         1429.0\n2...
# 20    {'data': 0          587.0\n1         1280.0\n2...
# 21    {'data': 0          661.0\n1         1448.0\n2...
# 22    {'data': 0          736.0\n1         1315.0\n2...
# 23    {'data': 0          588.0\n1         1447.0\n2...
# 24    {'data': 0          524.0\n1         1214.0\n2...
# 25    {'data': 0          615.0\n1         1548.0\n2...
# 26    {'data': 0          647.0\n1         1513.0\n2...
# 27    {'data': 0          587.0\n1         1396.0\n2...
# 28    {'data': 0          496.0\n1         1357.0\n2...
# 29    {'data': 0          598.0\n1         1379.0\n2...
# Name: coacts_10_layer-12, dtype: object
# coacts_00_layer-12 0     {'data': 0         1365.0\n1          750.0\n2...
# 1     {'data': 0         1538.0\n1          846.0\n2...
# 2     {'data': 0         1430.0\n1          819.0\n2...
# 3     {'data': 0         1551.0\n1          954.0\n2...
# 4     {'data': 0         1186.0\n1          889.0\n2...
# 5     {'data': 0         1135.0\n1          835.0\n2...
# 6     {'data': 0         1421.0\n1          848.0\n2...
# 7     {'data': 0         1483.0\n1          919.0\n2...
# 8     {'data': 0         1446.0\n1          761.0\n2...
# 9     {'data': 0         1294.0\n1          694.0\n2...
# 10    {'data': 0         1528.0\n1          895.0\n2...
# 11    {'data': 0         1294.0\n1          857.0\n2...
# 12    {'data': 0         1582.0\n1          672.0\n2...
# 13    {'data': 0         1355.0\n1          772.0\n2...
# 14    {'data': 0         1631.0\n1          803.0\n2...
# 15    {'data': 0         1463.0\n1          599.0\n2...
# 16    {'data': 0         1715.0\n1          793.0\n2...
# 17    {'data': 0         1395.0\n1          714.0\n2...
# 18    {'data': 0         1544.0\n1          748.0\n2...
# 19    {'data': 0         1597.0\n1          756.0\n2...
# 20    {'data': 0         1533.0\n1          840.0\n2...
# 21    {'data': 0         1524.0\n1          737.0\n2...
# 22    {'data': 0         1345.0\n1          766.0\n2...
# 23    {'data': 0         1538.0\n1          679.0\n2...
# 24    {'data': 0         1552.0\n1          862.0\n2...
# 25    {'data': 0         1585.0\n1          652.0\n2...
# 26    {'data': 0         1495.0\n1          629.0\n2...
# 27    {'data': 0         1459.0\n1          650.0\n2...
# 28    {'data': 0         1525.0\n1          664.0\n2...
# 29    {'data': 0         1466.0\n1          685.0\n2...
# Name: coacts_00_layer-12, dtype: object
# coactivations_layer-15 0     {'data': 0        0.0\n1        0.0\n2        ...
# 1     {'data': 0        0.0\n1        0.0\n2        ...
# 2     {'data': 0        0.0\n1        0.0\n2        ...
# 3     {'data': 0        0.0\n1        0.0\n2        ...
# 4     {'data': 0        0.0\n1        0.0\n2        ...
# 5     {'data': 0        0.0\n1        0.0\n2        ...
# 6     {'data': 0        0.0\n1        0.0\n2        ...
# 7     {'data': 0        0.0\n1        0.0\n2        ...
# 8     {'data': 0        0.0\n1        0.0\n2        ...
# 9     {'data': 0        0.0\n1        0.0\n2        ...
# 10    {'data': 0        0.0\n1        0.0\n2        ...
# 11    {'data': 0        0.0\n1        0.0\n2        ...
# 12    {'data': 0        0.0\n1        0.0\n2        ...
# 13    {'data': 0        0.0\n1        0.0\n2        ...
# 14    {'data': 0        0.0\n1        0.0\n2        ...
# 15    {'data': 0        0.0\n1        0.0\n2        ...
# 16    {'data': 0        0.0\n1        0.0\n2        ...
# 17    {'data': 0        0.0\n1        0.0\n2        ...
# 18    {'data': 0        0.0\n1        0.0\n2        ...
# 19    {'data': 0        0.0\n1        0.0\n2        ...
# 20    {'data': 0        0.0\n1        0.0\n2        ...
# 21    {'data': 0        0.0\n1        0.0\n2        ...
# 22    {'data': 0        0.0\n1        0.0\n2        ...
# 23    {'data': 0        0.0\n1        0.0\n2        ...
# 24    {'data': 0        0.0\n1        0.0\n2        ...
# 25    {'data': 0        0.0\n1        0.0\n2        ...
# 26    {'data': 0        0.0\n1        0.0\n2        ...
# 27    {'data': 0        0.0\n1        0.0\n2        ...
# 28    {'data': 0        0.0\n1        0.0\n2        ...
# 29    {'data': 0        0.0\n1        0.0\n2        ...
# Name: coactivations_layer-15, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-3d0016a27db2> in <module>
#       6 ]
#       7 paths = [os.path.expanduser("~/nta/results/{}".format(e)) for e in exps]
# ----> 8 df = load_many(paths)
#
# ~/nta/nupic.research/nupic/research/frameworks/dynamic_sparse/common/browser.py in load_many(experiment_paths, metrics)
#      84 def load_many(experiment_paths, metrics=None):
#      85     """Load several experiments into a single dataframe"""
# ---> 86     dataframes = [load(path, metrics) for path in experiment_paths]
#      87     return pd.concat(dataframes, axis=0, ignore_index=True, sort=False)
#      88
#
# ~/nta/nupic.research/nupic/research/frameworks/dynamic_sparse/common/browser.py in <listcomp>(.0)
#      84 def load_many(experiment_paths, metrics=None):
#      85     """Load several experiments into a single dataframe"""
# ---> 86     dataframes = [load(path, metrics) for path in experiment_paths]
#      87     return pd.concat(dataframes, axis=0, ignore_index=True, sort=False)
#      88
#
# ~/nta/nupic.research/nupic/research/frameworks/dynamic_sparse/common/browser.py in load(experiment_path, metrics)
#      74         if not progress:
#      75             continue
# ---> 76         dataframes.append(_get_value(progress, params, exp_name, base_path, metrics))
#      77
#      78     # concats all dataframes if there are any and return
#
# ~/nta/nupic.research/nupic/research/frameworks/dynamic_sparse/common/browser.py in _get_value(progress, params, exp_name, base_path, performance_metrics, full_metrics, exp_substring)
#     224                 stats[k].append(v)
#     225
# --> 226     return pd.DataFrame(stats)
#     227
#     228
#
# ~/miniconda3/envs/nta/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/envs/nta/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/miniconda3/envs/nta/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/miniconda3/envs/nta/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     326                            'length {idx_len}'
#     327                            .format(length=lengths[0], idx_len=len(index)))
# --> 328                     raise ValueError(msg)
#     329             else:
#     330                 index = ibase.default_index(lengths[0])
#
# ValueError: array length 1 does not match index length 30

# %%
df
# Out:
#                                     Experiment Name  train_acc_max  \
# 0  0_model=SparseModel,on_perc=[0.5, 0.1, 0.1, 1.0]       0.901230
# 1  0_model=SparseModel,on_perc=[0.5, 0.1, 0.1, 1.0]       0.935748
# 2  0_model=SparseModel,on_perc=[0.5, 0.1, 0.1, 1.0]       0.884777
# 3  0_model=SparseModel,on_perc=[0.5, 0.1, 0.1, 1.0]       0.946636
# 4  0_model=SparseModel,on_perc=[0.5, 0.1, 0.1, 1.0]       0.943560
#
#    train_acc_max_epoch  train_acc_min  train_acc_min_epoch  train_acc_median  \
# 0                    5       0.670686                    0          0.877331
# 1                   16       0.684211                    0          0.917586
# 2                    3       0.665414                    0          0.853823
# 3                   27       0.674202                    0          0.931696
# 4                   26       0.689142                    0          0.929572
#
#    train_acc_last  val_acc_max  val_acc_max_epoch  val_acc_min  ...  \
# 0        0.901230     0.935737                  4     0.873433  ...
# 1        0.935016     0.961991                 17     0.880878  ...
# 2        0.884777     0.942790                  3     0.879310  ...
# 3        0.945220     0.966693                 25     0.866771  ...
# 4        0.941314     0.966693                 22     0.890674  ...
#
#          model  momentum                                         net_params  \
# 0  SparseModel       0.0  {'boost_strength': 1.5, 'boost_strength_factor...
# 1  SparseModel       0.0  {'boost_strength': 1.5, 'boost_strength_factor...
# 2  SparseModel       0.0  {'boost_strength': 1.5, 'boost_strength_factor...
# 3  SparseModel       0.0  {'boost_strength': 1.5, 'boost_strength_factor...
# 4  SparseModel       0.0  {'boost_strength': 1.5, 'boost_strength_factor...
#
#            network  on_perc optim_alg                          prune_methods  \
# 0  gsc_sparse_dsnn    0.425       SGD  None-dynamic-conv-dynamic-linear-None
# 1  gsc_sparse_dsnn    0.425       SGD  None-dynamic-conv-dynamic-linear-None
# 2  gsc_sparse_dsnn    0.425       SGD  None-dynamic-conv-dynamic-linear-None
# 3  gsc_sparse_dsnn    0.425       SGD  None-dynamic-conv-dynamic-linear-None
# 4  gsc_sparse_dsnn    0.425       SGD  None-dynamic-conv-dynamic-linear-None
#
#    test_noise  track_coactivation_variants  weight_decay
# 0       False                         True          0.01
# 1       False                         True          0.01
# 2       False                         True          0.01
# 3       False                         True          0.01
# 4       False                         True          0.01
#
# [5 rows x 42 columns]

# %%
fro
